# %%
import os
import sys
import csv
import xlsxwriter

from fuzzywuzzy import fuzz
from fuzzywuzzy import process

# %%
# User input

base = "tblTopsMatchSmall.csv"
match = "tblWegmansMatch.csv"
base_field = "topsDesc"
match_field = "wegmansDesc"
method = "sort"
threshold = 60

# %%
def main():
    try:
        data_dir = ".\\excel\\data\\"
        archive_dir = ".\\excel\\archive\\"

        # Open base file 
        with open(data_dir + base, "r") as file:
            base_file = csv.DictReader(file)
            base_lst = []
            header_lst = []
            
            # Copy dictionary rows into a list, and extract headers into a list
            for row in base_file:
                for key in row:
                    if key not in header_lst:
                        header_lst.append(key)
                base_lst.append(row)
        
        # Open file to match records against the base file
        with open(data_dir + match, "r") as file:
            match_file = csv.DictReader(file)
            match_lst = []
            
            # Copy dictionary rows into a list
            for row in match_file:
                match_lst.append(row)
        
        # For dictionary row in the base file list...
        write_lst = []
        for base_row in base_lst:
            best_match = ("No Match", 0)
            row_lst = []
            
            # Match each row against the current base row
            for match_row in match_lst:
                match_ratio = fuzzy_match(base_row[base_field], match_row[match_field], method)
                
                # If the match ratio is less than threshold, skip record
                if match_ratio < threshold:
                    continue
                # Else, assign the highest ratio (linear search)
                elif match_ratio > best_match[1]:
                    best_match = (match_row[match_field], match_ratio)
            print(f"[{base_row[base_field]} | {best_match[0]}] Match Ratio: {best_match[1]}")
            
            # For each row
            for header in header_lst:
                row_lst.append(base_row[header])
            
            # For each row
            row_lst.extend(list(best_match))
            write_lst.append(row_lst)

        workbook = xlsxwriter.Workbook(archive_dir + f"match-{method}.xlsx")
        worksheet = workbook.add_worksheet()
        for col_num, data in enumerate(header_lst):
            worksheet.write(0, col_num, data)
        for row_num, row_data in enumerate(write_lst):
            if row_num == 0:
                continue
            for col_num, col_data in enumerate(row_data):
                worksheet.write(row_num, col_num, col_data)
        workbook.close()
    except:
        if not os.path.exists(archive_dir):
            os.makedirs(archive_dir)
        if not os.path.exists(data_dir):
            os.makedirs(data_dir)

# %%
def fuzzy_match(base, match, method):
    if method == "ratio":
        return fuzz.ratio(base.lower(), match.lower())
    elif method == "pratio":
        return fuzz.partial_ratio(base.lower(), match.lower())
    elif method == "sort":
        return fuzz.token_sort_ratio(base, match)
    elif method == "set":
        return fuzz.token_set_ratio(base, match)
    else:
        print("ERROR: Invalid match method.")
        raise

# %%
main()
# Out:
# [ORGANIC DRESSING BALSAMIC VINAIGRETTE | ORG DRESSING WHITE BALSAMIC VINAIGRETTE] Match Ratio: 87
# [ORGANIC DRESSING CAESAR | DRESSING CAESAR CRMY GARLIC] Match Ratio: 80
# [ORGANIC DRESSING FRENCH | ORGANIC DRESSING LEMON] Match Ratio: 84
# [ORGANIC DRESSING HONEY MUSTARD | DRESSING POURABLE HONEY MUSTARD NATURAL] Match Ratio: 75
# [ORGANIC DRESSING HNY MUSTARD | ORGANIC DRESSING LEMON] Match Ratio: 72
# [ORGANIC DRESSING ITALIAN | ORGANIC DRESSING LEMON] Match Ratio: 83
# [ORGANIC DRESSING RANCH | DRESSING LT RANCH] Match Ratio: 77
# [ORGANIC DRESSING TUSCAN ITALIAN | ORG DRESSING ITALIAN ZESTY VINAI] Match Ratio: 76
# [DRESSING POURABLE SRIRACHA RANCH | DRESSING LT RANCH] Match Ratio: 65
# [DRESSING POURABLE TZATZIKI | DIP TZATZIKI] Match Ratio: 63
# [DRESSING POURABLE BLUEBERRY MAPLE BALSAMIC | DRESSING POURABLE BALSAMIC VINAIGRETTE NATURAL] Match Ratio: 66
# [DRESSING POURABLE CREAMY ITALIAN WHITE BALSAMIC | DRESSING POURABLE BALSAMIC VINAIGRETTE NATURAL] Match Ratio: 73
# [MAYONNAISE REAL | MAYONNAISE LIGHT] Match Ratio: 65
# [MAYONNAISE | MAYONNAISE LIGHT] Match Ratio: 77
# [MAYONNAISE REAL | MAYONNAISE LIGHT] Match Ratio: 65
# [ORGANIC CROUTONS SEASONED | ORGANIC CROUTONS SEASONED] Match Ratio: 100
# [ORGANIC CROUTONS CAESAR | ORGANIC CROUTONS CAESAR] Match Ratio: 100
# [TARTAR SAUCE | TARTAR SAUCE NATURAL] Match Ratio: 75
# [CROUTONS CAESAR | ORGANIC CROUTONS CAESAR] Match Ratio: 79
# [CROUTONS CAESAR | ORGANIC CROUTONS CAESAR] Match Ratio: 79
# [CROUTONS CHEESE/GARLIC | CROUTONS TWICE BAKED CHEESE/GARLIC] Match Ratio: 79
# [CROUTONS CHEESE/GARLIC | CROUTONS TWICE BAKED CHEESE/GARLIC] Match Ratio: 79
# [CROUTONS ITALIAN SEASONED | CROUTONS SEASONED NATURAL] Match Ratio: 84
# [CROUTONS HERB SEASONED | ORGANIC CROUTONS SEASONED] Match Ratio: 81
# [CROUTONS HERB SEASONED | ORGANIC CROUTONS SEASONED] Match Ratio: 81
# [DRESSING ITALIAN CREAMY | DRESSING ITALIAN CREAMY] Match Ratio: 100
# [DRESSING ITALIAN | DRESSING ITALIAN CREAMY] Match Ratio: 82
# [DRESSING ITALIAN | DRESSING ITALIAN CREAMY] Match Ratio: 82
# [DRESSING 1000 ISLAND | DRESSING 1000 ISLAND] Match Ratio: 100
# [DRESSING 1000 ISLAND | DRESSING 1000 ISLAND] Match Ratio: 100
# [DRESSING BALSAMIC VINIAGRETTE | DRESSING BASIL VINAIGRETTE] Match Ratio: 84
# [DRESSING BLUE CHEESE | DRESSING BLUBE CHEESE] Match Ratio: 98
# [DRESSING BLUE CHEESE | DRESSING BLUBE CHEESE] Match Ratio: 98
# [DRESSING RANCH BUTTERMILK | DRESSING RANCH CRMY] Match Ratio: 77
# [DRESSING CAESAR | DRESSING CAESAR MIGHTY] Match Ratio: 81
# [DRESSING CAESAR | DRESSING CAESAR MIGHTY] Match Ratio: 81
# [DRESSING FRENCH CALIFORNIA | DRESSING FRENCH] Match Ratio: 73
# [DRESSING FRENCH CALIFORNIA | DRESSING FRENCH] Match Ratio: 73
# [DRESSING RANCH CREAMY | DRESSING RANCH CRMY] Match Ratio: 95
# [DRESSING FRENCH TRADITIONAL | DRESSING ITALIAN TRADITIONAL] Match Ratio: 80
# [DRESSING FRENCH | DRESSING FRENCH] Match Ratio: 100
# [DRESSING PEPPRCORN RANCH | DRESSING RANCH PEPPER] Match Ratio: 89
# [DRESSING GREEK | DRESSING FRENCH] Match Ratio: 76
# [DRESSING HONEY MUSTARD | MUSTARD DIJON HONEY] Match Ratio: 83
# [DRESSING ITALIAN ROBUSTO | DRESSING ITALIAN PARMESAN] Match Ratio: 78
# [DRESSING POURABLE ITALIAN PARMESAN | DRESSING ITALIAN PARMESAN] Match Ratio: 85
# [DRESSING RANCH | DRESSING LT RANCH] Match Ratio: 90
# [DRESSING RANCH BACON | DRESSING RANCH CRMY] Match Ratio: 82
# [DRESSING RANCH BACON | DRESSING RANCH CRMY] Match Ratio: 82

# %%
# Backup

def main():
    try:
        data_dir = ".\\excel\\data\\"
        archive_dir = ".\\excel\\archive\\"

        with open(data_dir + "tblTopsMatch.csv", "r") as file:
            base_file = csv.DictReader(file)
            base_lst = []
            header_lst = []

            for row in base_file:
                for key in row:
                    if key not in header_lst:
                        header_lst.append(key)
                base_lst.append(row)
        
        with open(data_dir + "tblWegmansMatch.csv", "r") as file:
            match_file = csv.DictReader(file)
            match_lst = []

            for row in match_file:
                match_lst.append(row)

        write_lst = []
        for base_row in base_lst:
            best_match = ("No Match", 0)
            row_lst = []
            for match_row in match_lst:
                set_ratio = fuzz.token_sort_ratio(base_row["topsDesc"], match_row["wegmansDesc"])
                if set_ratio < 60:
                    continue
                elif set_ratio > best_match[1]:
                    best_match = (match_row["wegmansDesc"], set_ratio)
            print(base_row["topsDesc"], best_match)
            
            for header in header_lst:
                row_lst.append(base_row[header])
                
            row_lst.extend(list(best_match))
            write_lst.append(row_lst)

        workbook = xlsxwriter.Workbook(archive_dir + "write_list.xlsx")
        worksheet = workbook.add_worksheet()
        for col_num, data in enumerate(header_lst):
            worksheet.write(0, col_num, data)
        for row_num, row_data in enumerate(write_lst):
            if row_num == 0:
                continue
            for col_num, col_data in enumerate(row_data):
                worksheet.write(row_num, col_num, col_data)
        workbook.close()
    except:
        if not os.path.exists(archive_dir):
            os.makedirs(archive_dir)
        if not os.path.exists(data_dir):
            os.makedirs(data_dir)
